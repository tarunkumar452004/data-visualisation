# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
data= pd.read_csv("student.csv")

# %%
data.head()
# Out:
#   school Gender   age  traveltime  studytime  failures  absences    G1    G2  \
# 0     GP      F  18.0         2.0        2.0       0.0       6.0   5.0   6.0
# 1     GP      F  17.0         1.0        2.0       0.0       4.0   5.0   5.0
# 2     GP      F  15.0         1.0        2.0       3.0      10.0   7.0   8.0
# 3     GP      F  15.0         1.0        3.0       0.0       2.0  15.0  14.0
# 4     GP      F  16.0         1.0        2.0       0.0       4.0   6.0  10.0
#
#      G3  attendence grade
# 0   6.0        18.0     A
# 1   6.0        17.0     A
# 2  10.0        15.0     A
# 3  15.0        15.0     A
# 4  10.0        16.0     A

# %%
df = pd.DataFrame(data)

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(x="grade", y="G3", data=df)
plt.title("Box Plot of Grade vs. G3 Score")
plt.xlabel("Grade")
plt.ylabel("G3 Score")
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.violinplot(x="grade", y="G3", data=df)
plt.title("Violin Plot of Grade vs. G3 Score")
plt.xlabel("Grade")
plt.ylabel("G3 Score")
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.scatterplot(x="attendence", y="G3", data=df)
plt.title("Scatter Plot of Attendance vs. G3 Score")
plt.xlabel("Attendance")
plt.ylabel("G3 Score")
plt.show()
